# %%
# 🟢 Part A – Basic Exploration
# •	Load the dataset and display the first 10 rows.
import __future__
import numpy as np
import pandas as pd
# Import visualization libraries and set favourite grid style
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
# Read in the dataset
iris = pd.read_csv('Iris.csv')
iris.head(10)
iris.info()


# •	Use .describe() to summarize numeric features.
iris.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# ...

# %%
# •	Use .describe() to summarize numeric features.
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# 🟡 Part B – Filtering & Sorting
# •	Filter rows where sepal_length > 5.
filtered_sepal = iris[iris['SepalLengthCm'] > 5]
print(filtered_sepal.head())
# •	Select only petal_length and species columns.
petal_species = iris[['PetalLengthCm', 'Species']]
print(petal_species.head())
# •	Get all rows where species is versicolor.
versicolor_rows = iris[iris['Species'] == 'Iris-versicolor']
print(versicolor_rows.head())
# •	Sort the data by sepal_width in descending order.
sorted_by_sepal_width = iris.sort_values(by='SepalWidthCm', ascending=False)
print("\n🔹 Data sorted by SepalWidthCm (descending):")
print(sorted_by_sepal_width.head())
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
#    PetalLengthCm      Species
# 0            1.4  Iris-setosa
# 1            1.4  Iris-setosa
# 2            1.3  Iris-setosa
# 3            1.5  Iris-setosa
# 4            1.4  Iris-setosa
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# ...

# %%
# 🟠 Part C – Grouping & Aggregation
# •	Group the dataset by species and compute:
grouped = iris.groupby('Species')
#    - Mean
mean_values = grouped.mean(numeric_only=True)
print("🔹 Mean values grouped by species:")
print(mean_values)
#    - Max
max_values = grouped.max(numeric_only=True)
print("\n🔹 Max values grouped by species:")
print(max_values)
#    - Count
count_values = grouped.count()
print("\n🔹 Count of entries grouped by species:")
print(count_values)

# •	Which species has the highest average petal_length?
highest_avg_petal_length_species = mean_values['PetalLengthCm'].idxmax()
highest_avg_value = mean_values['PetalLengthCm'].max()
# Out:
# 🔹 Mean values grouped by species:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026
#
# 🔹 Max values grouped by species:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       50            5.8           4.4            1.9           0.6
# Iris-versicolor  100            7.0           3.4            5.1           1.8
# Iris-virginica   150            7.9           3.8            6.9           2.5
#
# 🔹 Count of entries grouped by species:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# ...

# %%
# 🔵 Part D – Visualization

# •	Plot a histogram of sepal_length.
# plt.figure(figsize=(8, 5))
sns.histplot(data=iris, x='SepalLengthCm', bins=20,kde=True, color='skyblue')
plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()
# •	Create a boxplot of petal_width by species.
plt.figure(figsize=(8, 5))
sns.boxplot(data=iris, x='Species', y='PetalWidthCm', palette='Set2')
plt.title('Boxplot of Petal Width by Species')
plt.xlabel('Species')
plt.ylabel('Petal Width (cm)')
plt.show()

# •	Draw a scatter plot of sepal_length vs petal_length, color by species.
plt.figure(figsize=(8, 5))
sns.scatterplot(data=iris, x='SepalLengthCm', y='PetalLengthCm', hue='Species', palette='Set1')
plt.title('Sepal Length vs Petal Length by Species')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.legend(title='Species')
plt.show()

# •	Use seaborn.pairplot() to visualize all numerical relationships.
sns.pairplot(iris.drop(columns='Id'), hue='Species', palette='husl')
plt.suptitle("Pairplot of Iris Dataset", y=1.02)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12104\2054991443.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris, x='Species', y='PetalWidthCm', palette='Set2')

# %%
# •	Display column names and data types.
print(iris.dtypes)
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# •	Print the number of rows and columns (shape).
print(iris.shape)
# Out:
# (150, 6)
